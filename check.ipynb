# %%
import pandas as pd

# %%
df=pd.read_csv(r'sythetic data\tbl_trolley_maintenance_50k.csv')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49992 entries, 0 to 49991
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   maintenanceId   49992 non-null  int64
#  1   type            49992 non-null  str
#  2   reason          49992 non-null  str
#  3   completedNotes  42563 non-null  str
#  4   doneBy          49992 non-null  int64
#  5   image1          1745 non-null   str
#  6   image2          859 non-null    str
#  7   createdOn       49992 non-null  str
#  8   modifiedOn      42563 non-null  str
#  9   status          49992 non-null  int64
#  10  trolleyId       49992 non-null  int64
# dtypes: int64(4), str(7)
# memory usage: 7.4 MB

# %%
df['reason'].unique()
# Out:
# <ArrowStringArray>
# [          'Frame Damage', 'Broken & Needs Welding',      'Structural Damage',
#                'Accident',       'Brake Adjustment',      'Parts Replacement',
#           'Motor Failure',      'Oiling & Greasing',  'Cleaning & Inspection',
#        'Battery replaced',        'Wheel Alignment']
# Length: 11, dtype: str
